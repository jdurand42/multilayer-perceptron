# %%
import numpy as np
import pandas as pd

# %%
data_path = "../data/data.csv"

header = ['id', 'diagnosis']

for i in range(30):
    header.append(f'F{i}')

df = pd.read_csv(data_path, names=header)
df.head(5)
# Out:
#          id diagnosis     F0     F1      F2      F3       F4       F5      F6  \
# 0    842302         M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517         M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903         M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301         M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402         M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         F7  ...    F20    F21     F22     F23     F24     F25     F26     F27  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#       F28      F29
# ...

# %%
df.describe()
# Out:
#                  id          F0          F1          F2           F3  \
# count  5.690000e+02  569.000000  569.000000  569.000000   569.000000
# mean   3.037183e+07   14.127292   19.289649   91.969033   654.889104
# std    1.250206e+08    3.524049    4.301036   24.298981   351.914129
# min    8.670000e+03    6.981000    9.710000   43.790000   143.500000
# 25%    8.692180e+05   11.700000   16.170000   75.170000   420.300000
# 50%    9.060240e+05   13.370000   18.840000   86.240000   551.100000
# 75%    8.813129e+06   15.780000   21.800000  104.100000   782.700000
# max    9.113205e+08   28.110000   39.280000  188.500000  2501.000000
#
#                F4          F5          F6          F7          F8  ...  \
# count  569.000000  569.000000  569.000000  569.000000  569.000000  ...
# mean     0.096360    0.104341    0.088799    0.048919    0.181162  ...
# std      0.014064    0.052813    0.079720    0.038803    0.027414  ...
# ...

# %%
Y = df[['diagnosis']]

X = df.drop(labels=['diagnosis', 'id'], axis=1, inplace=False)
Y.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %%
X.head()
# Out:
#       F0     F1      F2      F3       F4       F5      F6       F7      F8  \
# 0  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001  0.14710  0.2419
# 1  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869  0.07017  0.1812
# 2  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974  0.12790  0.2069
# 3  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414  0.10520  0.2597
# 4  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980  0.10430  0.1809
#
#         F9  ...    F20    F21     F22     F23     F24     F25     F26     F27  \
# 0  0.07871  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.05667  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.05999  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.09744  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.05883  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#       F28      F29
# 0  0.4601  0.11890
# ...

# %%
Y = Y['diagnosis'].apply(lambda x: 1 if x == 'M' else 0)
Y.describe()
# Out:
# count    569.000000
# mean       0.372583
# std        0.483918
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: diagnosis, dtype: float64

# %%
# Normalization
# zscore

stds = []
means = []
# X = X.to_numpy()
for feature in X.columns:
    stds.append(X[feature].to_numpy().std())
    means.append(X[feature].to_numpy().mean())
print("stds: ", stds)
print("means: ", means)

raw = X.copy()

i = 0
for feature in X.columns:
    X[feature] = (X[feature] - means[i]) / stds[i]
    i += 1
# Out:
# stds:  [3.520950760711062, 4.297254637090421, 24.27761929305318, 351.60475406323, 0.014051764066591203, 0.05276632912535515, 0.07964972534603185, 0.03876873246147477, 0.027390180864268532, 0.007054155881537345, 0.27706894152536526, 0.551163426903576, 2.0200770991455244, 45.45101341563996, 0.0029998783671144756, 0.01789243586828196, 0.030159523121970472, 0.006164860746471701, 0.008259104387588135, 0.0026437447504047374, 4.828992576060772, 6.1408543185890005, 33.57300156682593, 568.8564589532671, 0.022812356935544644, 0.15719817109455372, 0.20844087461170602, 0.06567455451119314, 0.06181307854455481, 0.01804538930859499]
# ...

# %%
# print(raw.head(2))
X.head(2)
# Out:
#          F0        F1        F2        F3        F4        F5        F6  \
# 0  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874
# 1  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
#
#          F7        F8        F9  ...       F20       F21       F22       F23  \
# 0  2.532475  2.217515  2.255747  ...  1.886690 -1.359293  2.303601  2.001237
# 1  0.548144  0.001392 -0.868652  ...  1.805927 -0.369203  1.535126  1.890489
#
#         F24       F25       F26       F27       F28       F29
# 0  1.307686  2.616665  2.109526  2.296076  2.750622  1.937015
# 1 -0.375612 -0.430444 -0.146749  1.087084 -0.243890  0.281190
#
# [2 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

print(len(X))
print(300 / 569 * 100)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=300/569)
# Out:
# 569
# 52.72407732864674

# %%
import importlib
imported_module = importlib.import_module("MLP")
importlib.reload(imported_module)
from MLP import MultiLayerPerceptron

mlp = MultiLayerPerceptron(seed=1)

mlp.add_layer(size=32)
mlp.add_layer(size=32)
# mlp.add_layer(size=5, label="hidden_layer")
# mlp.add_layer(size=8, label="hidden_layer")
mlp.add_layer(label="out`put_layer")
# print(X.to_numpy())
mlp.fit(X_train.to_numpy(), Y_train.to_numpy(),
        verbose=False, epochs=200,
        normalization={'stds': stds, 'means': means},
        _print=True,
        X_test=X_test.to_numpy(),
        Y_test=Y_test.to_numpy())
# Out:
# 1/200:
# r2: -0.3148845514404197
# loss: 0.2841024792585942
# score: 0.543859649122807
# 2/200:
# r2: 0.23292992095316045
# loss: 0.16573813342286248
# score: 0.7719298245614035
# 3/200:
# r2: 0.4631844792667398
# loss: 0.1159878410448594
# score: 0.8070175438596491
# 4/200:
# r2: 0.5789161158771061
# loss: 0.09098211346699636
# score: 0.8947368421052632
# 5/200:
# r2: 0.647375120725636
# loss: 0.07619041712853289
# score: 0.8947368421052632
# 6/200:
# r2: 0.6933398436087335
# loss: 0.06625898115933182
# score: 0.8947368421052632
# 7/200:
# r2: 0.7269013007680387
# loss: 0.05900747518031294
# score: 0.9298245614035088
# 8/200:
# r2: 0.7527171970299587
# loss: 0.05342952529546599
# score: 0.9298245614035088
# 9/200:
# r2: 0.773257781311679
# loss: 0.04899139351160399
# score: 0.9298245614035088
# 10/200:
# r2: 0.7900022953729423
# loss: 0.04537346526568005
# score: 0.9473684210526315
# 11/200:
# r2: 0.8039180949051333
# loss: 0.0423667274166194
# score: 0.9473684210526315
# 12/200:
# ...

# %%
# evaluate

from sklearn.metrics import r2_score, accuracy_score
from sklearn.metrics import confusion_matrix
# import matplotlib

y_pred = mlp.predict(X_test.to_numpy())
print('score: ', accuracy_score(Y_test, y_pred))

cm = confusion_matrix(y_pred, Y_test.to_numpy())
print(cm)
# Out:
# score:  1.0
# [[39  0]
#  [ 0 18]]

# %%
import math

def binary_cross_entropy(p, y):
    # r = ((y * np.log(p + 1e15)) + ((1 - y) * np.log(1 - p + 1e15)))
    # print(r)
    # r = r.mean()
    e = 1e-15
    r = 0
    for i in range(0, len(p)):
        r += (y[i] * math.log(p[i]+e)) + ((1 - y[i]) * math.log(1 - p[i]+e))
        r = -r / len(p)
    return r

y_pred_raw = mlp.predict(X_test.to_numpy(), raw=True)
e = binary_cross_entropy(y_pred_raw, Y_test.to_numpy())
print(e)
e = binary_cross_entropy(y_pred, Y_test.to_numpy())
print(e)

# print(y_pred_raws)
# Out:
# 8.460823523067278e-07
# -1.914177628664062e-17

# %%
mlp.export()
# Out:
# successfuly exported in ./mlp.pkl
